# %%
import warnings
warnings.filterwarnings("ignore")
import anndata as ad
import pandas as pd
import scanpy as sc
import numpy as np
import sys
sys.path.append("../../../main/")
import scglue

# %%
import os 
os.chdir("../../../DATA/Mouse_embryo/")

# %%
rna = ad.read_h5ad("rna.h5ad")
atac = ad.read_h5ad("peakMat.h5ad")

# %%
scglue.data.get_gene_annotation(
    rna, gtf="../Mouse_embryo/gencode.vM25.chr_patch_hapl_scaff.annotation.gtf.gz",
    gtf_by="gene_name"
)

# %%
rna = rna[:,~rna.var["chrom"].isna()]

# %%
rna.layers["counts"] = rna.X
sc.pp.highly_variable_genes(rna, n_top_genes=2000, flavor="seurat_v3", layer="counts")

# %%
split = atac.var_names.str.split(r"[:-]")
atac.var["chrom"] = split.map(lambda x: x[0])
atac.var["chromStart"] = split.map(lambda x: x[1]).astype(int)
atac.var["chromEnd"] = split.map(lambda x: x[2]).astype(int)
# atac.var.head()

# %%
guidance = scglue.genomics.rna_anchored_guidance_graph(rna, atac)
# guidance
# Out:
# window_graph: 100%|██████████| 15140/15140 [00:02<00:00, 6821.76it/s]

# %%
atac.obs_names = [i.split("-")[0] for i in list(atac.obs_names)]
atac = atac[rna.obs_names]
atac.obsm["spatial"] = rna.obsm["spatial"]

# %%
scglue.data.lsi(atac, n_components=100, n_iter=15)

# %%
from itertools import chain

# %%
guidance_hvf = guidance.subgraph(chain(
    rna.var.query("highly_variable").index,
    atac.var.query("highly_variable").index
)).copy()

# %%
rna.X = rna.layers["counts"]
sc.pp.normalize_total(rna)
sc.pp.log1p(rna)
sc.pp.scale(rna)
sc.tl.pca(rna, n_comps=100, svd_solver="auto")

# %%
scglue.models.configure_dataset(
    rna, "NB", use_highly_variable=True,
    use_layer="counts", use_rep="X_pca",
)
scglue.models.configure_dataset(
    atac, "NB", use_highly_variable=True,use_rep="X_lsi",
)

# %%
glue = scglue.models.fit_SCGLUE(
    {"rna": rna, "atac": atac}, guidance_hvf,
    model=scglue.models.SCGLUEModel,
    fit_kws={"directory": "glue"},
)
# Out:
# [INFO] fit_SCGLUE: Pretraining SCGLUE model...
# [INFO] autodevice: Using GPU 1 as computation device.
# [INFO] check_graph: Checking variable coverage...
# [INFO] check_graph: Checking edge attributes...
# [INFO] check_graph: Checking self-loops...
# [INFO] check_graph: Checking graph symmetry...
# [INFO] SCGLUEModel: Setting `graph_batch_size` = 19866
# [INFO] SCGLUEModel: Setting `max_epochs` = 781
# [INFO] SCGLUEModel: Setting `patience` = 66
# [INFO] SCGLUEModel: Setting `reduce_lr_patience` = 33
# [INFO] SCGLUETrainer: Using training directory: "glue/pretrain"
# [INFO] SCGLUETrainer: [Epoch 10] train={'g_nll': 0.518, 'g_kl': 0.004, 'g_elbo': 0.523, 'x_rna_nll': 0.241, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.25, 'x_atac_nll': 0.131, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.133, 'dsc_loss': 0.686, 'vae_loss': 0.404, 'gen_loss': 0.37}, val={'g_nll': 0.514, 'g_kl': 0.004, 'g_elbo': 0.519, 'x_rna_nll': 0.228, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.236, 'x_atac_nll': 0.13, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.132, 'dsc_loss': 0.688, 'vae_loss': 0.388, 'gen_loss': 0.354}, 1.1s elapsed
# [INFO] SCGLUETrainer: [Epoch 20] train={'g_nll': 0.475, 'g_kl': 0.006, 'g_elbo': 0.481, 'x_rna_nll': 0.226, 'x_rna_kl': 0.007, 'x_rna_elbo': 0.233, 'x_atac_nll': 0.126, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.128, 'dsc_loss': 0.685, 'vae_loss': 0.38, 'gen_loss': 0.346}, val={'g_nll': 0.474, 'g_kl': 0.006, 'g_elbo': 0.481, 'x_rna_nll': 0.199, 'x_rna_kl': 0.006, 'x_rna_elbo': 0.205, 'x_atac_nll': 0.127, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.128, 'dsc_loss': 0.689, 'vae_loss': 0.353, 'gen_loss': 0.318}, 3.7s elapsed
# [INFO] SCGLUETrainer: [Epoch 30] train={'g_nll': 0.452, 'g_kl': 0.008, 'g_elbo': 0.46, 'x_rna_nll': 0.227, 'x_rna_kl': 0.007, 'x_rna_elbo': 0.234, 'x_atac_nll': 0.125, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.126, 'dsc_loss': 0.688, 'vae_loss': 0.379, 'gen_loss': 0.344}, val={'g_nll': 0.451, 'g_kl': 0.008, 'g_elbo': 0.459, 'x_rna_nll': 0.208, 'x_rna_kl': 0.007, 'x_rna_elbo': 0.215, 'x_atac_nll': 0.122, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.123, 'dsc_loss': 0.698, 'vae_loss': 0.356, 'gen_loss': 0.321}, 3.7s elapsed
# [INFO] SCGLUETrainer: [Epoch 40] train={'g_nll': 0.44, 'g_kl': 0.009, 'g_elbo': 0.449, 'x_rna_nll': 0.222, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.23, 'x_atac_nll': 0.121, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.122, 'dsc_loss': 0.689, 'vae_loss': 0.37, 'gen_loss': 0.335}, val={'g_nll': 0.44, 'g_kl': 0.009, 'g_elbo': 0.449, 'x_rna_nll': 0.202, 'x_rna_kl': 0.007, 'x_rna_elbo': 0.209, 'x_atac_nll': 0.121, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.122, 'dsc_loss': 0.693, 'vae_loss': 0.349, 'gen_loss': 0.314}, 1.0s elapsed
# [INFO] SCGLUETrainer: [Epoch 50] train={'g_nll': 0.434, 'g_kl': 0.009, 'g_elbo': 0.443, 'x_rna_nll': 0.214, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.222, 'x_atac_nll': 0.121, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.122, 'dsc_loss': 0.69, 'vae_loss': 0.363, 'gen_loss': 0.328}, val={'g_nll': 0.433, 'g_kl': 0.009, 'g_elbo': 0.442, 'x_rna_nll': 0.202, 'x_rna_kl': 0.007, 'x_rna_elbo': 0.209, 'x_atac_nll': 0.121, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.122, 'dsc_loss': 0.696, 'vae_loss': 0.348, 'gen_loss': 0.313}, 1.0s elapsed
# [INFO] SCGLUETrainer: [Epoch 60] train={'g_nll': 0.429, 'g_kl': 0.008, 'g_elbo': 0.438, 'x_rna_nll': 0.214, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.222, 'x_atac_nll': 0.118, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.119, 'dsc_loss': 0.692, 'vae_loss': 0.359, 'gen_loss': 0.325}, val={'g_nll': 0.428, 'g_kl': 0.008, 'g_elbo': 0.436, 'x_rna_nll': 0.216, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.224, 'x_atac_nll': 0.122, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.123, 'dsc_loss': 0.691, 'vae_loss': 0.365, 'gen_loss': 0.33}, 3.6s elapsed
# [INFO] SCGLUETrainer: [Epoch 70] train={'g_nll': 0.426, 'g_kl': 0.008, 'g_elbo': 0.434, 'x_rna_nll': 0.214, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.223, 'x_atac_nll': 0.118, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.119, 'dsc_loss': 0.691, 'vae_loss': 0.36, 'gen_loss': 0.325}, val={'g_nll': 0.428, 'g_kl': 0.008, 'g_elbo': 0.436, 'x_rna_nll': 0.193, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.2, 'x_atac_nll': 0.12, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.122, 'dsc_loss': 0.697, 'vae_loss': 0.339, 'gen_loss': 0.305}, 3.6s elapsed
# [INFO] SCGLUETrainer: [Epoch 80] train={'g_nll': 0.424, 'g_kl': 0.008, 'g_elbo': 0.433, 'x_rna_nll': 0.212, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.221, 'x_atac_nll': 0.117, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.119, 'dsc_loss': 0.692, 'vae_loss': 0.357, 'gen_loss': 0.322}, val={'g_nll': 0.424, 'g_kl': 0.008, 'g_elbo': 0.433, 'x_rna_nll': 0.202, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.21, 'x_atac_nll': 0.118, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.119, 'dsc_loss': 0.693, 'vae_loss': 0.347, 'gen_loss': 0.312}, 3.6s elapsed
# Epoch 00086: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 00086: reducing learning rate of group 0 to 2.0000e-04.
# [INFO] LRScheduler: Learning rate reduction: step 1
# [INFO] SCGLUETrainer: [Epoch 90] train={'g_nll': 0.423, 'g_kl': 0.008, 'g_elbo': 0.431, 'x_rna_nll': 0.207, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.216, 'x_atac_nll': 0.117, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.119, 'dsc_loss': 0.691, 'vae_loss': 0.352, 'gen_loss': 0.317}, val={'g_nll': 0.422, 'g_kl': 0.008, 'g_elbo': 0.431, 'x_rna_nll': 0.196, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.204, 'x_atac_nll': 0.119, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.12, 'dsc_loss': 0.691, 'vae_loss': 0.342, 'gen_loss': 0.307}, 3.6s elapsed
# [INFO] SCGLUETrainer: [Epoch 100] train={'g_nll': 0.422, 'g_kl': 0.008, 'g_elbo': 0.431, 'x_rna_nll': 0.211, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.22, 'x_atac_nll': 0.116, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.118, 'dsc_loss': 0.692, 'vae_loss': 0.355, 'gen_loss': 0.32}, val={'g_nll': 0.422, 'g_kl': 0.008, 'g_elbo': 0.431, 'x_rna_nll': 0.2, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.209, 'x_atac_nll': 0.122, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.123, 'dsc_loss': 0.693, 'vae_loss': 0.349, 'gen_loss': 0.315}, 3.7s elapsed
# [INFO] SCGLUETrainer: [Epoch 110] train={'g_nll': 0.422, 'g_kl': 0.008, 'g_elbo': 0.43, 'x_rna_nll': 0.21, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.219, 'x_atac_nll': 0.117, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.118, 'dsc_loss': 0.692, 'vae_loss': 0.354, 'gen_loss': 0.319}, val={'g_nll': 0.424, 'g_kl': 0.008, 'g_elbo': 0.433, 'x_rna_nll': 0.194, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.202, 'x_atac_nll': 0.122, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.123, 'dsc_loss': 0.692, 'vae_loss': 0.343, 'gen_loss': 0.308}, 3.7s elapsed
# [INFO] SCGLUETrainer: [Epoch 120] train={'g_nll': 0.422, 'g_kl': 0.008, 'g_elbo': 0.431, 'x_rna_nll': 0.212, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.221, 'x_atac_nll': 0.116, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.117, 'dsc_loss': 0.692, 'vae_loss': 0.356, 'gen_loss': 0.321}, val={'g_nll': 0.423, 'g_kl': 0.008, 'g_elbo': 0.431, 'x_rna_nll': 0.19, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.198, 'x_atac_nll': 0.121, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.122, 'dsc_loss': 0.691, 'vae_loss': 0.338, 'gen_loss': 0.303}, 3.6s elapsed
# Epoch 00129: reducing learning rate of group 0 to 2.0000e-05.
# Epoch 00129: reducing learning rate of group 0 to 2.0000e-05.
# [INFO] LRScheduler: Learning rate reduction: step 2
# [INFO] SCGLUETrainer: [Epoch 130] train={'g_nll': 0.423, 'g_kl': 0.008, 'g_elbo': 0.431, 'x_rna_nll': 0.212, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.221, 'x_atac_nll': 0.118, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.119, 'dsc_loss': 0.692, 'vae_loss': 0.357, 'gen_loss': 0.323}, val={'g_nll': 0.421, 'g_kl': 0.008, 'g_elbo': 0.43, 'x_rna_nll': 0.2, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.208, 'x_atac_nll': 0.118, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.119, 'dsc_loss': 0.691, 'vae_loss': 0.344, 'gen_loss': 0.31}, 3.7s elapsed
# [INFO] SCGLUETrainer: [Epoch 140] train={'g_nll': 0.422, 'g_kl': 0.008, 'g_elbo': 0.431, 'x_rna_nll': 0.211, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.22, 'x_atac_nll': 0.117, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.119, 'dsc_loss': 0.692, 'vae_loss': 0.356, 'gen_loss': 0.321}, val={'g_nll': 0.421, 'g_kl': 0.008, 'g_elbo': 0.43, 'x_rna_nll': 0.206, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.214, 'x_atac_nll': 0.12, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.122, 'dsc_loss': 0.69, 'vae_loss': 0.353, 'gen_loss': 0.318}, 3.7s elapsed
# [INFO] SCGLUETrainer: [Epoch 150] train={'g_nll': 0.423, 'g_kl': 0.008, 'g_elbo': 0.431, 'x_rna_nll': 0.207, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.217, 'x_atac_nll': 0.117, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.118, 'dsc_loss': 0.691, 'vae_loss': 0.352, 'gen_loss': 0.317}, val={'g_nll': 0.423, 'g_kl': 0.008, 'g_elbo': 0.431, 'x_rna_nll': 0.202, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.21, 'x_atac_nll': 0.117, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.119, 'dsc_loss': 0.691, 'vae_loss': 0.346, 'gen_loss': 0.312}, 3.7s elapsed
# [INFO] SCGLUETrainer: [Epoch 160] train={'g_nll': 0.422, 'g_kl': 0.008, 'g_elbo': 0.431, 'x_rna_nll': 0.209, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.219, 'x_atac_nll': 0.117, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.118, 'dsc_loss': 0.692, 'vae_loss': 0.354, 'gen_loss': 0.32}, val={'g_nll': 0.423, 'g_kl': 0.008, 'g_elbo': 0.431, 'x_rna_nll': 0.204, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.212, 'x_atac_nll': 0.118, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.119, 'dsc_loss': 0.692, 'vae_loss': 0.349, 'gen_loss': 0.314}, 3.7s elapsed
# [INFO] SCGLUETrainer: [Epoch 170] train={'g_nll': 0.423, 'g_kl': 0.008, 'g_elbo': 0.431, 'x_rna_nll': 0.207, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.216, 'x_atac_nll': 0.116, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.117, 'dsc_loss': 0.692, 'vae_loss': 0.35, 'gen_loss': 0.316}, val={'g_nll': 0.422, 'g_kl': 0.008, 'g_elbo': 0.431, 'x_rna_nll': 0.199, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.207, 'x_atac_nll': 0.121, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.123, 'dsc_loss': 0.693, 'vae_loss': 0.347, 'gen_loss': 0.313}, 3.7s elapsed
# [INFO] SCGLUETrainer: [Epoch 180] train={'g_nll': 0.423, 'g_kl': 0.008, 'g_elbo': 0.431, 'x_rna_nll': 0.206, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.215, 'x_atac_nll': 0.117, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.118, 'dsc_loss': 0.692, 'vae_loss': 0.351, 'gen_loss': 0.316}, val={'g_nll': 0.422, 'g_kl': 0.008, 'g_elbo': 0.43, 'x_rna_nll': 0.193, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.201, 'x_atac_nll': 0.117, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.119, 'dsc_loss': 0.69, 'vae_loss': 0.337, 'gen_loss': 0.302}, 3.8s elapsed
# Epoch 00189: reducing learning rate of group 0 to 2.0000e-06.
# Epoch 00189: reducing learning rate of group 0 to 2.0000e-06.
# [INFO] LRScheduler: Learning rate reduction: step 3
# [INFO] SCGLUETrainer: [Epoch 190] train={'g_nll': 0.422, 'g_kl': 0.008, 'g_elbo': 0.431, 'x_rna_nll': 0.209, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.218, 'x_atac_nll': 0.116, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.117, 'dsc_loss': 0.691, 'vae_loss': 0.352, 'gen_loss': 0.318}, val={'g_nll': 0.423, 'g_kl': 0.008, 'g_elbo': 0.432, 'x_rna_nll': 0.191, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.199, 'x_atac_nll': 0.12, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.121, 'dsc_loss': 0.692, 'vae_loss': 0.337, 'gen_loss': 0.302}, 3.6s elapsed
# [INFO] SCGLUETrainer: [Epoch 200] train={'g_nll': 0.423, 'g_kl': 0.008, 'g_elbo': 0.431, 'x_rna_nll': 0.21, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.219, 'x_atac_nll': 0.117, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.119, 'dsc_loss': 0.692, 'vae_loss': 0.355, 'gen_loss': 0.32}, val={'g_nll': 0.422, 'g_kl': 0.008, 'g_elbo': 0.431, 'x_rna_nll': 0.195, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.203, 'x_atac_nll': 0.122, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.123, 'dsc_loss': 0.691, 'vae_loss': 0.343, 'gen_loss': 0.309}, 3.6s elapsed
# [INFO] SCGLUETrainer: [Epoch 210] train={'g_nll': 0.422, 'g_kl': 0.008, 'g_elbo': 0.43, 'x_rna_nll': 0.213, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.222, 'x_atac_nll': 0.117, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.118, 'dsc_loss': 0.692, 'vae_loss': 0.358, 'gen_loss': 0.323}, val={'g_nll': 0.423, 'g_kl': 0.008, 'g_elbo': 0.431, 'x_rna_nll': 0.202, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.21, 'x_atac_nll': 0.119, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.12, 'dsc_loss': 0.69, 'vae_loss': 0.347, 'gen_loss': 0.313}, 1.0s elapsed
# [INFO] SCGLUETrainer: [Epoch 220] train={'g_nll': 0.423, 'g_kl': 0.008, 'g_elbo': 0.431, 'x_rna_nll': 0.209, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.219, 'x_atac_nll': 0.116, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.118, 'dsc_loss': 0.692, 'vae_loss': 0.353, 'gen_loss': 0.319}, val={'g_nll': 0.422, 'g_kl': 0.008, 'g_elbo': 0.43, 'x_rna_nll': 0.209, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.218, 'x_atac_nll': 0.119, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.12, 'dsc_loss': 0.69, 'vae_loss': 0.355, 'gen_loss': 0.32}, 1.0s elapsed
# 2024-12-17 20:43:32,022 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# [INFO] EarlyStopping: Restoring checkpoint "155"...
# [INFO] EarlyStopping: Restoring checkpoint "155"...
# [INFO] fit_SCGLUE: Estimating balancing weight...
# [INFO] estimate_balancing_weight: Clustering cells...
# [INFO] estimate_balancing_weight: Matching clusters...
# [INFO] estimate_balancing_weight: Matching array shape = (14, 11)...
# [INFO] estimate_balancing_weight: Estimating balancing weight...
# [INFO] fit_SCGLUE: Fine-tuning SCGLUE model...
# [INFO] check_graph: Checking variable coverage...
# [INFO] check_graph: Checking edge attributes...
# [INFO] check_graph: Checking self-loops...
# [INFO] check_graph: Checking graph symmetry...
# [INFO] SCGLUEModel: Setting `graph_batch_size` = 19866
# [INFO] SCGLUEModel: Setting `align_burnin` = 131
# [INFO] SCGLUEModel: Setting `max_epochs` = 781
# [INFO] SCGLUEModel: Setting `patience` = 66
# [INFO] SCGLUEModel: Setting `reduce_lr_patience` = 33
# [INFO] SCGLUETrainer: Using training directory: "glue/fine-tune"
# [INFO] SCGLUETrainer: [Epoch 10] train={'g_nll': 0.422, 'g_kl': 0.008, 'g_elbo': 0.43, 'x_rna_nll': 0.207, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.216, 'x_atac_nll': 0.116, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.117, 'dsc_loss': 0.688, 'vae_loss': 0.351, 'gen_loss': 0.316}, val={'g_nll': 0.421, 'g_kl': 0.008, 'g_elbo': 0.429, 'x_rna_nll': 0.238, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.246, 'x_atac_nll': 0.118, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.12, 'dsc_loss': 0.73, 'vae_loss': 0.383, 'gen_loss': 0.347}, 1.1s elapsed
# [INFO] SCGLUETrainer: [Epoch 20] train={'g_nll': 0.422, 'g_kl': 0.008, 'g_elbo': 0.43, 'x_rna_nll': 0.21, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.219, 'x_atac_nll': 0.117, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.118, 'dsc_loss': 0.689, 'vae_loss': 0.355, 'gen_loss': 0.32}, val={'g_nll': 0.421, 'g_kl': 0.008, 'g_elbo': 0.429, 'x_rna_nll': 0.226, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.235, 'x_atac_nll': 0.12, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.121, 'dsc_loss': 0.728, 'vae_loss': 0.373, 'gen_loss': 0.337}, 1.1s elapsed
# [INFO] SCGLUETrainer: [Epoch 30] train={'g_nll': 0.422, 'g_kl': 0.008, 'g_elbo': 0.43, 'x_rna_nll': 0.208, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.217, 'x_atac_nll': 0.116, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.117, 'dsc_loss': 0.693, 'vae_loss': 0.352, 'gen_loss': 0.317}, val={'g_nll': 0.424, 'g_kl': 0.008, 'g_elbo': 0.432, 'x_rna_nll': 0.228, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.236, 'x_atac_nll': 0.124, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.125, 'dsc_loss': 0.745, 'vae_loss': 0.379, 'gen_loss': 0.341}, 1.1s elapsed
# [INFO] SCGLUETrainer: [Epoch 40] train={'g_nll': 0.422, 'g_kl': 0.008, 'g_elbo': 0.431, 'x_rna_nll': 0.211, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.22, 'x_atac_nll': 0.115, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.117, 'dsc_loss': 0.685, 'vae_loss': 0.354, 'gen_loss': 0.32}, val={'g_nll': 0.422, 'g_kl': 0.008, 'g_elbo': 0.431, 'x_rna_nll': 0.252, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.261, 'x_atac_nll': 0.118, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.119, 'dsc_loss': 0.728, 'vae_loss': 0.397, 'gen_loss': 0.361}, 1.0s elapsed
# [INFO] SCGLUETrainer: [Epoch 50] train={'g_nll': 0.423, 'g_kl': 0.008, 'g_elbo': 0.431, 'x_rna_nll': 0.206, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.215, 'x_atac_nll': 0.115, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.117, 'dsc_loss': 0.685, 'vae_loss': 0.349, 'gen_loss': 0.315}, val={'g_nll': 0.421, 'g_kl': 0.008, 'g_elbo': 0.43, 'x_rna_nll': 0.237, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.245, 'x_atac_nll': 0.117, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.118, 'dsc_loss': 0.732, 'vae_loss': 0.381, 'gen_loss': 0.344}, 1.0s elapsed
# [INFO] SCGLUETrainer: [Epoch 60] train={'g_nll': 0.423, 'g_kl': 0.008, 'g_elbo': 0.431, 'x_rna_nll': 0.207, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.216, 'x_atac_nll': 0.116, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.118, 'dsc_loss': 0.682, 'vae_loss': 0.351, 'gen_loss': 0.317}, val={'g_nll': 0.421, 'g_kl': 0.008, 'g_elbo': 0.429, 'x_rna_nll': 0.222, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.23, 'x_atac_nll': 0.12, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.121, 'dsc_loss': 0.736, 'vae_loss': 0.368, 'gen_loss': 0.332}, 1.0s elapsed
# [INFO] SCGLUETrainer: [Epoch 70] train={'g_nll': 0.423, 'g_kl': 0.008, 'g_elbo': 0.432, 'x_rna_nll': 0.207, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.216, 'x_atac_nll': 0.115, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.117, 'dsc_loss': 0.683, 'vae_loss': 0.35, 'gen_loss': 0.315}, val={'g_nll': 0.422, 'g_kl': 0.008, 'g_elbo': 0.43, 'x_rna_nll': 0.236, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.245, 'x_atac_nll': 0.122, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.123, 'dsc_loss': 0.745, 'vae_loss': 0.385, 'gen_loss': 0.347}, 1.0s elapsed
# [INFO] SCGLUETrainer: [Epoch 80] train={'g_nll': 0.424, 'g_kl': 0.009, 'g_elbo': 0.432, 'x_rna_nll': 0.204, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.214, 'x_atac_nll': 0.116, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.117, 'dsc_loss': 0.682, 'vae_loss': 0.348, 'gen_loss': 0.314}, val={'g_nll': 0.423, 'g_kl': 0.009, 'g_elbo': 0.432, 'x_rna_nll': 0.231, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.24, 'x_atac_nll': 0.125, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.126, 'dsc_loss': 0.739, 'vae_loss': 0.384, 'gen_loss': 0.347}, 1.1s elapsed
# [INFO] SCGLUETrainer: [Epoch 90] train={'g_nll': 0.424, 'g_kl': 0.009, 'g_elbo': 0.433, 'x_rna_nll': 0.204, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.213, 'x_atac_nll': 0.115, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.117, 'dsc_loss': 0.683, 'vae_loss': 0.347, 'gen_loss': 0.313}, val={'g_nll': 0.422, 'g_kl': 0.009, 'g_elbo': 0.431, 'x_rna_nll': 0.244, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.252, 'x_atac_nll': 0.12, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.122, 'dsc_loss': 0.732, 'vae_loss': 0.392, 'gen_loss': 0.355}, 1.1s elapsed
# [INFO] SCGLUETrainer: [Epoch 100] train={'g_nll': 0.424, 'g_kl': 0.009, 'g_elbo': 0.433, 'x_rna_nll': 0.204, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.213, 'x_atac_nll': 0.115, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.117, 'dsc_loss': 0.68, 'vae_loss': 0.347, 'gen_loss': 0.313}, val={'g_nll': 0.424, 'g_kl': 0.009, 'g_elbo': 0.433, 'x_rna_nll': 0.226, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.235, 'x_atac_nll': 0.126, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.127, 'dsc_loss': 0.736, 'vae_loss': 0.379, 'gen_loss': 0.342}, 1.0s elapsed
# [INFO] SCGLUETrainer: [Epoch 110] train={'g_nll': 0.425, 'g_kl': 0.009, 'g_elbo': 0.434, 'x_rna_nll': 0.208, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.217, 'x_atac_nll': 0.115, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.117, 'dsc_loss': 0.676, 'vae_loss': 0.351, 'gen_loss': 0.317}, val={'g_nll': 0.424, 'g_kl': 0.009, 'g_elbo': 0.433, 'x_rna_nll': 0.232, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.241, 'x_atac_nll': 0.12, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.121, 'dsc_loss': 0.742, 'vae_loss': 0.379, 'gen_loss': 0.342}, 1.1s elapsed
# [INFO] SCGLUETrainer: [Epoch 120] train={'g_nll': 0.425, 'g_kl': 0.009, 'g_elbo': 0.433, 'x_rna_nll': 0.208, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.216, 'x_atac_nll': 0.116, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.117, 'dsc_loss': 0.678, 'vae_loss': 0.351, 'gen_loss': 0.317}, val={'g_nll': 0.424, 'g_kl': 0.009, 'g_elbo': 0.432, 'x_rna_nll': 0.233, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.241, 'x_atac_nll': 0.123, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.125, 'dsc_loss': 0.736, 'vae_loss': 0.383, 'gen_loss': 0.346}, 1.0s elapsed
# [INFO] SCGLUETrainer: [Epoch 130] train={'g_nll': 0.425, 'g_kl': 0.009, 'g_elbo': 0.433, 'x_rna_nll': 0.205, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.214, 'x_atac_nll': 0.115, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.116, 'dsc_loss': 0.676, 'vae_loss': 0.347, 'gen_loss': 0.313}, val={'g_nll': 0.424, 'g_kl': 0.009, 'g_elbo': 0.433, 'x_rna_nll': 0.246, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.254, 'x_atac_nll': 0.129, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.13, 'dsc_loss': 0.748, 'vae_loss': 0.402, 'gen_loss': 0.364}, 3.7s elapsed
# [INFO] SCGLUETrainer: [Epoch 140] train={'g_nll': 0.425, 'g_kl': 0.009, 'g_elbo': 0.434, 'x_rna_nll': 0.205, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.214, 'x_atac_nll': 0.115, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.116, 'dsc_loss': 0.675, 'vae_loss': 0.348, 'gen_loss': 0.314}, val={'g_nll': 0.425, 'g_kl': 0.009, 'g_elbo': 0.433, 'x_rna_nll': 0.238, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.246, 'x_atac_nll': 0.124, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.125, 'dsc_loss': 0.737, 'vae_loss': 0.389, 'gen_loss': 0.352}, 3.1s elapsed
# [INFO] SCGLUETrainer: [Epoch 150] train={'g_nll': 0.425, 'g_kl': 0.009, 'g_elbo': 0.433, 'x_rna_nll': 0.212, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.221, 'x_atac_nll': 0.116, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.117, 'dsc_loss': 0.671, 'vae_loss': 0.355, 'gen_loss': 0.321}, val={'g_nll': 0.423, 'g_kl': 0.009, 'g_elbo': 0.432, 'x_rna_nll': 0.231, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.239, 'x_atac_nll': 0.124, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.126, 'dsc_loss': 0.72, 'vae_loss': 0.382, 'gen_loss': 0.346}, 3.2s elapsed
# [INFO] SCGLUETrainer: [Epoch 160] train={'g_nll': 0.425, 'g_kl': 0.009, 'g_elbo': 0.434, 'x_rna_nll': 0.207, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.216, 'x_atac_nll': 0.114, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.116, 'dsc_loss': 0.67, 'vae_loss': 0.349, 'gen_loss': 0.315}, val={'g_nll': 0.425, 'g_kl': 0.009, 'g_elbo': 0.434, 'x_rna_nll': 0.232, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.24, 'x_atac_nll': 0.126, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.127, 'dsc_loss': 0.734, 'vae_loss': 0.385, 'gen_loss': 0.349}, 3.2s elapsed
# Epoch 00166: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 00166: reducing learning rate of group 0 to 2.0000e-04.
# [INFO] LRScheduler: Learning rate reduction: step 1
# [INFO] SCGLUETrainer: [Epoch 170] train={'g_nll': 0.424, 'g_kl': 0.009, 'g_elbo': 0.433, 'x_rna_nll': 0.21, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.219, 'x_atac_nll': 0.115, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.116, 'dsc_loss': 0.686, 'vae_loss': 0.352, 'gen_loss': 0.318}, val={'g_nll': 0.424, 'g_kl': 0.009, 'g_elbo': 0.433, 'x_rna_nll': 0.238, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.247, 'x_atac_nll': 0.12, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.121, 'dsc_loss': 0.744, 'vae_loss': 0.385, 'gen_loss': 0.348}, 3.3s elapsed
# [INFO] SCGLUETrainer: [Epoch 180] train={'g_nll': 0.424, 'g_kl': 0.009, 'g_elbo': 0.433, 'x_rna_nll': 0.207, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.216, 'x_atac_nll': 0.115, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.117, 'dsc_loss': 0.672, 'vae_loss': 0.35, 'gen_loss': 0.317}, val={'g_nll': 0.425, 'g_kl': 0.009, 'g_elbo': 0.433, 'x_rna_nll': 0.241, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.25, 'x_atac_nll': 0.119, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.12, 'dsc_loss': 0.737, 'vae_loss': 0.388, 'gen_loss': 0.351}, 3.4s elapsed
# [INFO] SCGLUETrainer: [Epoch 190] train={'g_nll': 0.424, 'g_kl': 0.009, 'g_elbo': 0.433, 'x_rna_nll': 0.202, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.211, 'x_atac_nll': 0.115, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.116, 'dsc_loss': 0.678, 'vae_loss': 0.345, 'gen_loss': 0.311}, val={'g_nll': 0.424, 'g_kl': 0.009, 'g_elbo': 0.433, 'x_rna_nll': 0.238, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.247, 'x_atac_nll': 0.119, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.12, 'dsc_loss': 0.752, 'vae_loss': 0.384, 'gen_loss': 0.347}, 3.2s elapsed
# [INFO] SCGLUETrainer: [Epoch 200] train={'g_nll': 0.425, 'g_kl': 0.009, 'g_elbo': 0.434, 'x_rna_nll': 0.203, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.212, 'x_atac_nll': 0.115, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.116, 'dsc_loss': 0.671, 'vae_loss': 0.346, 'gen_loss': 0.312}, val={'g_nll': 0.423, 'g_kl': 0.009, 'g_elbo': 0.432, 'x_rna_nll': 0.248, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.257, 'x_atac_nll': 0.119, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.121, 'dsc_loss': 0.734, 'vae_loss': 0.395, 'gen_loss': 0.359}, 3.2s elapsed
# Epoch 00200: reducing learning rate of group 0 to 2.0000e-05.
# Epoch 00200: reducing learning rate of group 0 to 2.0000e-05.
# [INFO] LRScheduler: Learning rate reduction: step 2
# [INFO] SCGLUETrainer: [Epoch 210] train={'g_nll': 0.425, 'g_kl': 0.009, 'g_elbo': 0.433, 'x_rna_nll': 0.204, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.213, 'x_atac_nll': 0.115, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.116, 'dsc_loss': 0.675, 'vae_loss': 0.347, 'gen_loss': 0.313}, val={'g_nll': 0.424, 'g_kl': 0.009, 'g_elbo': 0.433, 'x_rna_nll': 0.243, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.251, 'x_atac_nll': 0.12, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.121, 'dsc_loss': 0.726, 'vae_loss': 0.39, 'gen_loss': 0.354}, 3.1s elapsed
# [INFO] SCGLUETrainer: [Epoch 220] train={'g_nll': 0.425, 'g_kl': 0.009, 'g_elbo': 0.434, 'x_rna_nll': 0.209, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.218, 'x_atac_nll': 0.114, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.116, 'dsc_loss': 0.676, 'vae_loss': 0.351, 'gen_loss': 0.317}, val={'g_nll': 0.425, 'g_kl': 0.009, 'g_elbo': 0.434, 'x_rna_nll': 0.222, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.23, 'x_atac_nll': 0.125, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.127, 'dsc_loss': 0.733, 'vae_loss': 0.374, 'gen_loss': 0.337}, 3.2s elapsed
# [INFO] SCGLUETrainer: [Epoch 230] train={'g_nll': 0.425, 'g_kl': 0.009, 'g_elbo': 0.433, 'x_rna_nll': 0.202, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.211, 'x_atac_nll': 0.115, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.116, 'dsc_loss': 0.671, 'vae_loss': 0.345, 'gen_loss': 0.311}, val={'g_nll': 0.426, 'g_kl': 0.009, 'g_elbo': 0.435, 'x_rna_nll': 0.248, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.257, 'x_atac_nll': 0.123, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.124, 'dsc_loss': 0.75, 'vae_loss': 0.399, 'gen_loss': 0.361}, 3.4s elapsed
# Epoch 00234: reducing learning rate of group 0 to 2.0000e-06.
# Epoch 00234: reducing learning rate of group 0 to 2.0000e-06.
# [INFO] LRScheduler: Learning rate reduction: step 3
# [INFO] SCGLUETrainer: [Epoch 240] train={'g_nll': 0.425, 'g_kl': 0.009, 'g_elbo': 0.434, 'x_rna_nll': 0.203, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.212, 'x_atac_nll': 0.115, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.117, 'dsc_loss': 0.674, 'vae_loss': 0.346, 'gen_loss': 0.312}, val={'g_nll': 0.426, 'g_kl': 0.009, 'g_elbo': 0.435, 'x_rna_nll': 0.244, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.252, 'x_atac_nll': 0.121, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.123, 'dsc_loss': 0.744, 'vae_loss': 0.393, 'gen_loss': 0.355}, 3.6s elapsed
# [INFO] SCGLUETrainer: [Epoch 250] train={'g_nll': 0.425, 'g_kl': 0.009, 'g_elbo': 0.434, 'x_rna_nll': 0.202, 'x_rna_kl': 0.009, 'x_rna_elbo': 0.211, 'x_atac_nll': 0.114, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.115, 'dsc_loss': 0.678, 'vae_loss': 0.343, 'gen_loss': 0.309}, val={'g_nll': 0.426, 'g_kl': 0.009, 'g_elbo': 0.435, 'x_rna_nll': 0.242, 'x_rna_kl': 0.008, 'x_rna_elbo': 0.25, 'x_atac_nll': 0.123, 'x_atac_kl': 0.002, 'x_atac_elbo': 0.125, 'dsc_loss': 0.741, 'vae_loss': 0.392, 'gen_loss': 0.355}, 3.4s elapsed
# 2024-12-17 20:53:53,411 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# [INFO] EarlyStopping: Restoring checkpoint "238"...
# [INFO] EarlyStopping: Restoring checkpoint "238"...

# %%
rna.obsm["X_glue"] = glue.encode_data("rna", rna)
atac.obsm["X_glue"] = glue.encode_data("atac", atac)

# %%
combined = ad.concat([rna, atac], label="omics")

# %%
sc.pp.neighbors(combined, use_rep="X_glue")
sc.tl.umap(combined)

# %%
sc.pl.umap(combined, color="omics")

# %%
import pandas as pd
def res_search_fixed_clus(adata, fixed_clus_count, increment=0.05):
    closest_count = np.inf  
    closest_res = None  
    
    for res in sorted(list(np.arange(0.1, 2, increment)), reverse=True):
        sc.tl.leiden(adata, random_state=0, resolution=res)
        count_unique_leiden = len(pd.DataFrame(adata.obs['leiden']).leiden.unique())
        current_diff = abs(count_unique_leiden - fixed_clus_count)
        if current_diff < closest_count:
            closest_count = current_diff
            closest_res = res
        if count_unique_leiden == fixed_clus_count:
            break

    return closest_res

# %%
res =  res_search_fixed_clus(combined, fixed_clus_count=17)

# %%
sc.tl.leiden(adata=combined, resolution=res)

# %%
t_rna = combined[combined.obs["omics"]=="0",]
t_atac = combined[combined.obs["omics"]=="1",]

# %%
sc.pl.spatial(t_rna, color="leiden",spot_size=1)
sc.pl.spatial(t_atac, color="leiden",spot_size=1)

# %%
# cluster = combined.obs['leiden']
# cluster.to_csv("rep1/GLUE_cluster.csv")
# umap = pd.DataFrame(combined.obsm["X_umap"])
# umap.to_csv("rep1/GLUE_umap.csv")
# embed = pd.DataFrame(combined.obsm["X_glue"])
# embed.to_csv("rep1/GLUE_embed.csv")
